# %% [markdown]
# <a href="https://colab.research.google.com/github/Fulim13/Pytorch_Learning/blob/main/Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Change to GPU to run faster

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # List all the package

# %%
! pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# absl-py                            1.4.0
# accelerate                         1.1.1
# aiohappyeyeballs                   2.4.3
# aiohttp                            3.10.10
# aiosignal                          1.3.1
# alabaster                          1.0.0
# albucore                           0.0.19
# albumentations                     1.4.20
# altair                             4.2.2
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.5.1
# arviz                              0.20.0
# astropy                            6.1.6
# astropy-iers-data                  0.2024.11.11.0.32.38
# astunparse                         1.6.3
# async-timeout                      4.0.3
# atpublic                           4.1.0
# ...

# %% [markdown]
# # List the files

# %%
! ls
# Out:
# sample_data

# %% [markdown]
# # Set up Github Repository and Push it with Colab Links

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Run IPYNB files that located in the Github and Save it back

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Managing Session

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
