# %%
import torch
import torch.nn as nn

# %% [markdown]
# # 3 inputs and 2 outputs Neural Network

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Create input_tensor with three features
input_tensor = torch.tensor([[1.2,2.1,3.2]]) # dimenstion 1 X 3

# %%
# Define first linear layer
linear_layer = nn.Linear(3,2) # output dimension 1 X 2

# %%
# Pass input through linear layer
output = linear_layer(input_tensor)
output
# Out:
# tensor([[-0.3211,  1.8574]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Weight and Bias

# %%
linear_layer.weight
# Out:
# Parameter containing:
# tensor([[-0.4982, -0.5471,  0.5090],
#         [ 0.1353, -0.0308,  0.3864]], requires_grad=True)

# %%
linear_layer.bias
# Out:
# Parameter containing:
# tensor([-0.2030,  0.5232], requires_grad=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Stacking Layer

# %%
import torch
import torch.nn as nn

input_tensor = torch.Tensor([[2, 3, 6, 7, 9, 3, 2, 1]])

# Implement a small neural network with exactly two linear layers
model = nn.Sequential(nn.Linear(8,1),
                      nn.Linear(1,1)
                     )

output = model(input_tensor)
print(output)
# Out:
# tensor([[-1.8485]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# # Activation Function

# %% [markdown]
# ## Sigmoid Function
#
# ![image.png](attachment:image.png)

# %%
input_tensor = torch.tensor([[6]])

# Create a sigmoid function and apply it on input_tensor
sigmoid = nn.Sigmoid()
probability = sigmoid(input_tensor)
print(probability)
# Out:
# tensor([[0.9975]])

# %% [markdown]
# ### Stacking Sigmoid Function

# %%
input_tensor = torch.tensor([[1.1,2.1,3.1,4.1,5.1,6.1]])

model = nn.Sequential(  
    nn.Linear(6, 4), # First linear layer  
    nn.Linear(4, 1), # Second linear layer  
    nn.Sigmoid() # Sigmoid activation function
)

output = model(input_tensor)
print(output)
# Out:
# tensor([[0.4532]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# # Softmax Function
#
# ![image.png](attachment:image.png)

# %%
input_tensor = torch.tensor([[4.3, 6.1, 2.3]])

prob = nn.Softmax(dim=-1) # last dimension of input tensor
output_tensor = prob(input_tensor)
output_tensor
# Out:
# tensor([[0.1392, 0.8420, 0.0188]])
